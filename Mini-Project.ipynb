# %% [markdown]
# # Importing necessary libraries

# %%
# import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
import os
from os import listdir
from PIL import Image
import tensorflow as tf
from keras.preprocessing import image
from tensorflow. keras.utils import img_to_array, array_to_img
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dropout, Dense
from sklearn. model_selection import train_test_split
from keras.models import model_from_json
from keras.utils import to_categorical

# %%
print(tf. __version__)
# Out:
# 2.14.0

# %% [markdown]
# # Defining the path of dataset directory

# %%
dataset_path ="C://Users//swamy//Desktop//final-2//pd1"

# %% [markdown]
# # Visualizing the images and Resize images

# %%
# Plotting 12 images to check dataset

plt.figure(figsize = (12, 12))
dataset_path = "C://Users//swamy//Desktop//final-2//pd1//Potato-Early_blight"

for i in range(1, 17):
    plt.subplot(4, 4, i)
    plt.tight_layout()
    rand_img = imread(dataset_path +'/'+ random.choice(sorted(os.listdir(dataset_path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10) # width of image
    plt.ylabel(rand_img.shape[0], fontsize = 10) # height of image

# %% [markdown]
# # Convert the images into a Numpy array and normalize them

# %%
# Converting Images to array 

def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, (256, 256))  
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
dataset_path = "C://Users//swamy//Desktop//final-2//pd1"
labels = os.listdir(dataset_path)

print(labels)
# Out:
# ['Corn-Common_rust', 'Potato-Early_blight', 'Wheat___Brown_Rust']

# %%
dataset_path = "C://Users//swamy//Desktop//final-2//pd1"
root_dir = listdir(dataset_path)
image_list, label_list = [], []
all_labels = ['Corn-Common_rust', 'Potato-Early_blight', 'Wheat___Brown_Rust']
binary_labels = [0, 1, 2]
temp = -1

# Reading and converting image to numpy array

for directory in root_dir:
  plant_image_list = listdir(f"{dataset_path}/{directory}")
  temp += 1
  for files in plant_image_list:
    image_path = f"{dataset_path}/{directory}/{files}"
    image_list.append(convert_image_to_array(image_path))
    label_list.append(binary_labels[temp])

# %% [markdown]
# # Visualize the class count and Check for class imbalance

# %%
# Visualize the number of classes count

label_counts = pd.DataFrame(label_list).value_counts()
label_counts.head()
# Out:
# 0    300
# 1    300
# 2    300
# dtype: int64

# %% [markdown]
# # it is a balanced dataset as we can see

# %%
# Next we will observe the shape of the image.

image_list[0].shape
# Out:
# (256, 256, 3)

# %%
# Checking the total number of the images which is the length of the labels list.

label_list = np.array(label_list)
label_list.shape
# Out:
# (900,)

# %% [markdown]
# # Splitting the dataset into train, validate and test sets

# %%
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %%
# Now we will normalize the dataset of our images. As pixel values ranges from 0 to 255 so we will divide each image pixel with 255 to normalize the dataset.

x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape(-1, 256, 256, 3)
x_test = x_test.reshape(-1, 256, 256, 3)

# %% [markdown]
# # Performing one-hot encoding on target variable

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# # Creating the model architecture, compile the model and then fit it using the training data

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding = "same",input_shape = (256, 256, 3), activation = "relu"))
model.add(MaxPooling2D(pool_size = (3, 3)))
model.add(Conv2D(16, (3, 3), padding = "same", activation = "relu"))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Flatten())
model.add(Dense(8, activation = "relu"))
model.add(Dense(3, activation = "softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 85, 85, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 85, 85, 16)        4624
#
#  max_pooling2d_1 (MaxPoolin  (None, 42, 42, 16)        0
#  g2D)
#
#  flatten (Flatten)           (None, 28224)             0
#
#  dense (Dense)               (None, 8)                 225800
#
#  dense_1 (Dense)             (None, 3)                 27
#
# =================================================================
# Total params: 231347 (903.70 KB)
# Trainable params: 231347 (903.70 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001), metrics = ['accuracy'])

# %%
# Splitting the training data set into training and validation data sets

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2, random_state = 10)

# %%
# Training the model

epochs = 50
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 37s 4s/step - loss: 1.0582 - accuracy: 0.4167 - val_loss: 1.0022 - val_accuracy: 0.6944
# Epoch 2/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.9649 - accuracy: 0.8003 - val_loss: 0.8948 - val_accuracy: 0.7222
# Epoch 3/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.8523 - accuracy: 0.7153 - val_loss: 0.7652 - val_accuracy: 0.9514
# Epoch 4/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.7100 - accuracy: 0.9688 - val_loss: 0.6277 - val_accuracy: 0.9792
# Epoch 5/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.5650 - accuracy: 0.9792 - val_loss: 0.4879 - val_accuracy: 0.9792
# Epoch 6/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.4295 - accuracy: 0.9809 - val_loss: 0.3718 - val_accuracy: 0.9792
# Epoch 7/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.3178 - accuracy: 0.9826 - val_loss: 0.2772 - val_accuracy: 0.9792
# Epoch 8/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.2318 - accuracy: 0.9809 - val_loss: 0.2124 - val_accuracy: 0.9861
# Epoch 9/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.1751 - accuracy: 0.9826 - val_loss: 0.1642 - val_accuracy: 0.9861
# Epoch 10/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.1352 - accuracy: 0.9826 - val_loss: 0.1338 - val_accuracy: 0.9861
# Epoch 11/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.1077 - accuracy: 0.9878 - val_loss: 0.1113 - val_accuracy: 0.9861
# Epoch 12/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0888 - accuracy: 0.9861 - val_loss: 0.0960 - val_accuracy: 0.9861
# Epoch 13/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0757 - accuracy: 0.9913 - val_loss: 0.0851 - val_accuracy: 0.9861
# Epoch 14/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0674 - accuracy: 0.9878 - val_loss: 0.0761 - val_accuracy: 0.9861
# Epoch 15/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0577 - accuracy: 0.9913 - val_loss: 0.0697 - val_accuracy: 0.9861
# Epoch 16/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0553 - accuracy: 0.9896 - val_loss: 0.0663 - val_accuracy: 0.9861
# Epoch 17/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0498 - accuracy: 0.9896 - val_loss: 0.0602 - val_accuracy: 0.9861
# Epoch 18/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0433 - accuracy: 0.9965 - val_loss: 0.0564 - val_accuracy: 0.9931
# Epoch 19/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0389 - accuracy: 0.9948 - val_loss: 0.0551 - val_accuracy: 0.9861
# Epoch 20/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0370 - accuracy: 0.9965 - val_loss: 0.0491 - val_accuracy: 0.9931
# Epoch 21/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0321 - accuracy: 0.9965 - val_loss: 0.0478 - val_accuracy: 0.9861
# Epoch 22/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.0293 - accuracy: 0.9965 - val_loss: 0.0442 - val_accuracy: 0.9931
# Epoch 23/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.0263 - accuracy: 0.9983 - val_loss: 0.0422 - val_accuracy: 0.9931
# Epoch 24/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.0257 - accuracy: 0.9965 - val_loss: 0.0395 - val_accuracy: 0.9931
# Epoch 25/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.0231 - accuracy: 0.9983 - val_loss: 0.0376 - val_accuracy: 0.9931
# Epoch 26/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.0210 - accuracy: 0.9983 - val_loss: 0.0383 - val_accuracy: 0.9931
# Epoch 27/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.0196 - accuracy: 0.9983 - val_loss: 0.0352 - val_accuracy: 0.9931
# Epoch 28/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.0176 - accuracy: 0.9983 - val_loss: 0.0333 - val_accuracy: 0.9931
# Epoch 29/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.0332 - val_accuracy: 0.9931
# Epoch 30/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.0153 - accuracy: 0.9983 - val_loss: 0.0315 - val_accuracy: 0.9931
# Epoch 31/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.0313 - val_accuracy: 0.9931
# Epoch 32/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.0298 - val_accuracy: 0.9931
# Epoch 33/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.0284 - val_accuracy: 0.9931
# Epoch 34/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.0297 - val_accuracy: 0.9931
# Epoch 35/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.0287 - val_accuracy: 0.9931
# Epoch 36/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.0266 - val_accuracy: 0.9931
# Epoch 37/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.0298 - val_accuracy: 0.9931
# Epoch 38/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0275 - val_accuracy: 0.9931
# Epoch 39/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0273 - val_accuracy: 0.9931
# Epoch 40/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.0285 - val_accuracy: 0.9931
# Epoch 41/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9931
# Epoch 42/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.0269 - val_accuracy: 0.9931
# Epoch 43/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0290 - val_accuracy: 0.9931
# Epoch 44/50
# 5/5 [==============================] - 12s 3s/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.0254 - val_accuracy: 0.9931
# Epoch 45/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 0.9931
# Epoch 46/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0253 - val_accuracy: 0.9931
# Epoch 47/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0281 - val_accuracy: 0.9931
# Epoch 48/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0232 - val_accuracy: 0.9931
# Epoch 49/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 0.9931
# Epoch 50/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0281 - val_accuracy: 0.9931

# %%
model.save("C://Users//swamy//Desktop//final-2//plant_disease_model2")
# Out:
# INFO:tensorflow:Assets written to: C://Users//swamy//Desktop//final-2//plant_disease_model2/assets
# INFO:tensorflow:Assets written to: C://Users//swamy//Desktop//final-2//plant_disease_model2/assets

# %% [markdown]
# # Plot the accuracy and loss against each epoch

# %%
# Plot the training history

plt.figure(figsize = (12, 5))
plt.plot(history.history['accuracy'], color = 'r')
plt.plot(history.history['val_accuracy'], color = 'b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %%
print("Calculating model accuracy")

scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1] * 100}")
# Out:
# Calculating model accuracy
# 6/6 [==============================] - 1s 186ms/step - loss: 0.0252 - accuracy: 0.9944
# Test Accuracy: 99.44444298744202

# %% [markdown]
# # Make predictions on testing data

# %%
y_pred = model.predict(x_test)
# Out:
# 6/6 [==============================] - 1s 175ms/step

# %% [markdown]
# # Visualizing the original and predicted labels for the test images

# %%
# Plotting image to compare

img = array_to_img(x_test[11])
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x273C54C5BE0>

# %%
# Finding max value from predition list and comaparing original value vs predicted

print("Originally : ", all_labels[np.argmax(y_test[11])])
print("Predicted : ", all_labels[np.argmax(y_pred[4])])
print(y_pred[2])
# Out:
# Originally :  Corn-Common_rust
# Predicted :  Corn-Common_rust
# [7.261674e-04 1.510293e-04 9.991228e-01]

# %%
for i in range(50):
    print (all_labels[np.argmax(y_test[i])], " ", all_labels[np.argmax(y_pred [1])])
# Out:
# Potato-Early_blight   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Wheat___Brown_Rust   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Wheat___Brown_Rust   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Wheat___Brown_Rust   Corn-Common_rust
# Wheat___Brown_Rust   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Wheat___Brown_Rust   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Wheat___Brown_Rust   Corn-Common_rust
# Wheat___Brown_Rust   Corn-Common_rust
# Wheat___Brown_Rust   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Wheat___Brown_Rust   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Wheat___Brown_Rust   Corn-Common_rust
# Wheat___Brown_Rust   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Wheat___Brown_Rust   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Wheat___Brown_Rust   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Wheat___Brown_Rust   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Wheat___Brown_Rust   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
